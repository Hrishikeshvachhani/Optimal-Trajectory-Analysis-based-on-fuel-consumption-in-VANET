# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Here, we are loading the data generated from the SUMO simulator. These data is then cleaned to get desired data suitable for our Machine Learning based approach.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the csv file which contains the data having 25000 vehicles and simulation of 50000 timestep

# %%
data = pd.read_csv('emission50000t_25000v.csv',delimiter=";")

# %% [markdown]
# Total 7979907 rows of data is obtained

# %%
data
# Out:
#          timestep_time  vehicle_CO  vehicle_CO2  vehicle_HC  vehicle_NOx  \
# 0                  0.0      164.78      2624.72        0.81         1.20
# 1                  1.0      147.37      3191.28        0.75         1.42
# 2                  1.0      164.78      2624.72        0.81         1.20
# 3                  2.0      146.32      5001.07        0.78         2.21
# 4                  2.0      147.60      3044.17        0.74         1.36
# ...                ...         ...          ...         ...          ...
# 7979902        49995.0         NaN          NaN         NaN          NaN
# 7979903        49996.0         NaN          NaN         NaN          NaN
# 7979904        49997.0         NaN          NaN         NaN          NaN
# 7979905        49998.0         NaN          NaN         NaN          NaN
# 7979906        49999.0         NaN          NaN         NaN          NaN
#
#          vehicle_PMx  vehicle_angle   vehicle_eclass  vehicle_electricity  \
# 0               0.07         186.58  HBEFA3/PC_G_EU4                  0.0
# 1               0.07         186.58  HBEFA3/PC_G_EU4                  0.0
# 2               0.07         300.61  HBEFA3/PC_G_EU4                  0.0
# 3               0.11         186.58  HBEFA3/PC_G_EU4                  0.0
# 4               0.07         300.61  HBEFA3/PC_G_EU4                  0.0
# ...              ...            ...              ...                  ...
# 7979902          NaN            NaN              NaN                  NaN
# 7979903          NaN            NaN              NaN                  NaN
# 7979904          NaN            NaN              NaN                  NaN
# 7979905          NaN            NaN              NaN                  NaN
# 7979906          NaN            NaN              NaN                  NaN
#
#          vehicle_fuel  vehicle_id   vehicle_lane  vehicle_noise  vehicle_pos  \
# 0                1.13         0.0   -338817486_0          55.94         5.10
# 1                1.37         0.0   -338817486_0          64.14         6.81
# 2                1.13         1.0  -62518623#1_0          55.94         5.10
# 3                2.15         0.0   -338817486_0          68.71        11.05
# 4                1.31         1.0  -62518623#1_0          63.18         6.61
# ...               ...         ...            ...            ...          ...
# 7979902           NaN         NaN            NaN            NaN          NaN
# 7979903           NaN         NaN            NaN            NaN          NaN
# 7979904           NaN         NaN            NaN            NaN          NaN
# 7979905           NaN         NaN            NaN            NaN          NaN
# 7979906           NaN         NaN            NaN            NaN          NaN
#
#         vehicle_route  vehicle_speed     vehicle_type  vehicle_waiting  \
# 0                  !0           0.00  DEFAULT_VEHTYPE              0.0
# 1                  !0           1.71  DEFAULT_VEHTYPE              0.0
# 2                  !1           0.00  DEFAULT_VEHTYPE              0.0
# 3                  !0           4.24  DEFAULT_VEHTYPE              0.0
# 4                  !1           1.51  DEFAULT_VEHTYPE              0.0
# ...               ...            ...              ...              ...
# 7979902           NaN            NaN              NaN              NaN
# 7979903           NaN            NaN              NaN              NaN
# 7979904           NaN            NaN              NaN              NaN
# 7979905           NaN            NaN              NaN              NaN
# 7979906           NaN            NaN              NaN              NaN
#
#          vehicle_x  vehicle_y
# 0         13229.54   13858.50
# 1         13229.34   13856.80
# 2          8550.01    7263.51
# 3         13228.85   13852.59
# 4          8548.71    7264.28
# ...            ...        ...
# 7979902        NaN        NaN
# 7979903        NaN        NaN
# 7979904        NaN        NaN
# 7979905        NaN        NaN
# 7979906        NaN        NaN
#
# [7979907 rows x 20 columns]

# %% [markdown]
# Columns of the data obtained are as below

# %%
data.columns
# Out:
# Index(['timestep_time', 'vehicle_CO', 'vehicle_CO2', 'vehicle_HC',
#        'vehicle_NOx', 'vehicle_PMx', 'vehicle_angle', 'vehicle_eclass',
#        'vehicle_electricity', 'vehicle_fuel', 'vehicle_id', 'vehicle_lane',
#        'vehicle_noise', 'vehicle_pos', 'vehicle_route', 'vehicle_speed',
#        'vehicle_type', 'vehicle_waiting', 'vehicle_x', 'vehicle_y'],
#       dtype='object')

# %% [markdown]
# We do not need all the data obtained from the simulator, so we drop few columns from the dataset

# %%
data.drop(['vehicle_CO', 'vehicle_CO2', 'vehicle_HC',
       'vehicle_NOx', 'vehicle_PMx', 'vehicle_angle', 'vehicle_eclass',
       'vehicle_electricity','vehicle_lane',
       'vehicle_noise', 'vehicle_pos', 'vehicle_route','vehicle_type'],axis=1,inplace=True)

# %%
data
# Out:
#          timestep_time  vehicle_fuel  vehicle_id  vehicle_speed  \
# 0                  0.0          1.13         0.0           0.00
# 1                  1.0          1.37         0.0           1.71
# 2                  1.0          1.13         1.0           0.00
# 3                  2.0          2.15         0.0           4.24
# 4                  2.0          1.31         1.0           1.51
# ...                ...           ...         ...            ...
# 7979902        49995.0           NaN         NaN            NaN
# 7979903        49996.0           NaN         NaN            NaN
# 7979904        49997.0           NaN         NaN            NaN
# 7979905        49998.0           NaN         NaN            NaN
# 7979906        49999.0           NaN         NaN            NaN
#
#          vehicle_waiting  vehicle_x  vehicle_y
# 0                    0.0   13229.54   13858.50
# 1                    0.0   13229.34   13856.80
# 2                    0.0    8550.01    7263.51
# 3                    0.0   13228.85   13852.59
# 4                    0.0    8548.71    7264.28
# ...                  ...        ...        ...
# 7979902              NaN        NaN        NaN
# 7979903              NaN        NaN        NaN
# 7979904              NaN        NaN        NaN
# 7979905              NaN        NaN        NaN
# 7979906              NaN        NaN        NaN
#
# [7979907 rows x 7 columns]

# %%
df = data

# %% [markdown]
# After droping certain features, we need to remove the null values from the dataset

# %%
df = df.dropna(axis=0)

# %% [markdown]
# This cleaned dataset is then stored in the csv file, so that we can use it later.

# %%
df.to_csv('emission50000t_25000v.csv')

# %%
df
# Out:
#          timestep_time  vehicle_fuel  vehicle_id  vehicle_speed  \
# 0                  0.0          1.13         0.0           0.00
# 1                  1.0          1.37         0.0           1.71
# 2                  1.0          1.13         1.0           0.00
# 3                  2.0          2.15         0.0           4.24
# 4                  2.0          1.31         1.0           1.51
# ...                ...           ...         ...            ...
# 7955858        25951.0          4.47     24775.0          15.53
# 7955859        25952.0          2.50     24775.0          16.29
# 7955860        25953.0          2.78     24775.0          17.13
# 7955861        25954.0          0.00     24775.0          17.08
# 7955862        25955.0          0.00     24775.0          16.73
#
#          vehicle_waiting  vehicle_x  vehicle_y
# 0                    0.0   13229.54   13858.50
# 1                    0.0   13229.34   13856.80
# 2                    0.0    8550.01    7263.51
# 3                    0.0   13228.85   13852.59
# 4                    0.0    8548.71    7264.28
# ...                  ...        ...        ...
# 7955858              0.0    8864.90    9829.10
# 7955859              0.0    8850.86    9837.35
# 7955860              0.0    8836.09    9846.03
# 7955861              0.0    8821.36    9854.68
# 7955862              0.0    8806.93    9863.15
#
# [7955863 rows x 7 columns]

# %% [markdown]
# Total number of uniques vehicles present in the simulation results

# %%
df['vehicle_id'].nunique()
# Out:
# 24508

# %% [markdown]
# After cleaning and removing dataset, finally we have 7955863 rows of data

# %%
df
# Out:
#          timestep_time  vehicle_fuel  vehicle_id  vehicle_speed  \
# 0                  0.0          1.13         0.0           0.00
# 1                  1.0          1.37         0.0           1.71
# 2                  1.0          1.13         1.0           0.00
# 3                  2.0          2.15         0.0           4.24
# 4                  2.0          1.31         1.0           1.51
# ...                ...           ...         ...            ...
# 7955858        25951.0          4.47     24775.0          15.53
# 7955859        25952.0          2.50     24775.0          16.29
# 7955860        25953.0          2.78     24775.0          17.13
# 7955861        25954.0          0.00     24775.0          17.08
# 7955862        25955.0          0.00     24775.0          16.73
#
#          vehicle_waiting  vehicle_x  vehicle_y
# 0                    0.0   13229.54   13858.50
# 1                    0.0   13229.34   13856.80
# 2                    0.0    8550.01    7263.51
# 3                    0.0   13228.85   13852.59
# 4                    0.0    8548.71    7264.28
# ...                  ...        ...        ...
# 7955858              0.0    8864.90    9829.10
# 7955859              0.0    8850.86    9837.35
# 7955860              0.0    8836.09    9846.03
# 7955861              0.0    8821.36    9854.68
# 7955862              0.0    8806.93    9863.15
#
# [7955863 rows x 7 columns]
